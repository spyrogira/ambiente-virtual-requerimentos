# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
sns.boxplot(x='item_price', data=df)
plt.xticks(rotation=90)
plt.title('Boxplot of Item Prices')
# Out:
# Text(0.5, 1.0, 'Boxplot of Item Prices')

# %%
px.bar(df, x='item_name', y='item_price', title='Bar Chart of Item Prices', labels={'item_name': 'Item Name', 'item_price': 'Item Price'}).show();

# %%
# !pip freeze > requirements.txt
